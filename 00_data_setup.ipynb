# %%
import pandas as pd

# %% [markdown]
# ## Prepare Co-Ocurrence Matrix

# %%
coocur_df = pd.read_excel('./00_raw_data/Nintendo_Cooccurrence_Matrix.xlsx')
coocur_df.rename(columns={'Unnamed: 0': 'Items'}, inplace=True)
coocur_df.head(5)
# Out:
#                          Items  Nintendo Switch  Zelda: Breath of the Wild  \
# 0              Nintendo Switch            50000                      30000
# 1    Zelda: Breath of the Wild            30000                     100000
# 2  Zelda: Tears of the Kingdom            50000                      20000
# 3          Super Mario Odyssey            60000                      15000
# 4          Mario Kart 8 Deluxe            40000                      10000
#
#    Zelda: Tears of the Kingdom  Super Mario Odyssey  Mario Kart 8 Deluxe  \
# 0                        50000                60000                40000
# 1                        20000                15000                10000
# 2                       150000                25000                15000
# 3                        25000               200000                30000
# 4                        15000                30000               150000
#
#    Mario Party Superstars  Sonic Generations  Sonic Mania  \
# 0                   20000              10000        10000
# 1                    5000               2000         3000
# 2                   10000               5000         5000
# 3                   20000               5000         5000
# 4                   10000               2000         3000
#
#    Animal Crossing: New Horizons  Splatoon 3  Pikmin 4  \
# 0                         100000       30000      5000
# 1                          30000       20000      2000
# 2                          30000       20000      2000
# 3                          25000       10000      2000
# 4                          13000       15000      1000
#
#    Nintendo Switch Pro Controller  Joy-Con Controllers (Pair)  \
# 0                           50000                       20000
# 1                            5000                        3000
# 2                           10000                        3000
# 3                            2000                        1000
# 4                            5000                        3000
#
#    Nintendo Switch Dock Set  Nintendo Switch Carrying Case  \
# 0                     10000                          10000
# 1                      2000                           2000
# 2                      2000                           2000
# 3                         0                              0
# 4                      2000                           1000
#
#    Nintendo Switch Screen Protector
# 0                              5000
# 1                              1000
# 2                              1000
# 3                                 0
# 4                                 0

# %%
#-- Prepare Co-ocurrence matrix for final format
coocur_df_final = coocur_df.melt(id_vars='Items', var_name='product2', value_name='cooccurrence_count')
coocur_df_final.rename(columns={'Items': 'product1'}, inplace=True)
coocur_df_final.tail(10)
# Out:
#                              product1                          product2  \
# 246                 Sonic Generations  Nintendo Switch Screen Protector
# 247                       Sonic Mania  Nintendo Switch Screen Protector
# 248     Animal Crossing: New Horizons  Nintendo Switch Screen Protector
# 249                        Splatoon 3  Nintendo Switch Screen Protector
# 250                          Pikmin 4  Nintendo Switch Screen Protector
# 251    Nintendo Switch Pro Controller  Nintendo Switch Screen Protector
# 252        Joy-Con Controllers (Pair)  Nintendo Switch Screen Protector
# 253          Nintendo Switch Dock Set  Nintendo Switch Screen Protector
# 254     Nintendo Switch Carrying Case  Nintendo Switch Screen Protector
# 255  Nintendo Switch Screen Protector  Nintendo Switch Screen Protector
#
#      cooccurrence_count
# 246                1000
# 247                1000
# 248               10000
# 249                5000
# 250                   0
# 251                   0
# 252                   0
# 253                1000
# 254                   0
# 255               10000

# %%
# remove self-cooccurrences
coocur_df_final = coocur_df_final[coocur_df_final['product1'] != coocur_df_final['product2']]

# %%
print('N rows before droping duplicates: ', coocur_df_final.shape)

# format dataframe so that product1 > product2 (alphabetically ordered) 
coocur_df_final[['product1', 'product2']] = coocur_df_final.apply(
    lambda row: sorted([row['product1'], row['product2']]), axis=1, result_type='expand'
)

# remove duplicate pairs (we only need one directional count (A, B), not (B, A))
coocur_df_final.drop_duplicates(ignore_index=True, keep='first', inplace=True)

print('N rows after droping duplicates: ', coocur_df_final.shape)

coocur_df_final.reset_index(drop=True, inplace=True)

coocur_df_final.head(10)
# Out:
# N rows before droping duplicates:  (240, 3)
# N rows after droping duplicates:  (120, 3)
#                         product1                     product2  \
# 0                Nintendo Switch    Zelda: Breath of the Wild
# 1                Nintendo Switch  Zelda: Tears of the Kingdom
# 2                Nintendo Switch          Super Mario Odyssey
# 3            Mario Kart 8 Deluxe              Nintendo Switch
# 4         Mario Party Superstars              Nintendo Switch
# 5                Nintendo Switch            Sonic Generations
# 6                Nintendo Switch                  Sonic Mania
# 7  Animal Crossing: New Horizons              Nintendo Switch
# 8                Nintendo Switch                   Splatoon 3
# 9                Nintendo Switch                     Pikmin 4
#
#    cooccurrence_count
# 0               30000
# 1               50000
# 2               60000
# 3               40000
# 4               20000
# 5               10000
# 6               10000
# 7              100000
# 8               30000
# 9                5000

# %% [markdown]
# #### Data Verification

# %%
# verification
coocur_df_final[(coocur_df_final['product1'] == 'Nintendo Switch')|(coocur_df_final['product2'] == 'Nintendo Switch')]
# Out:
#                          product1                          product2  \
# 0                 Nintendo Switch         Zelda: Breath of the Wild
# 1                 Nintendo Switch       Zelda: Tears of the Kingdom
# 2                 Nintendo Switch               Super Mario Odyssey
# 3             Mario Kart 8 Deluxe                   Nintendo Switch
# 4          Mario Party Superstars                   Nintendo Switch
# 5                 Nintendo Switch                 Sonic Generations
# 6                 Nintendo Switch                       Sonic Mania
# 7   Animal Crossing: New Horizons                   Nintendo Switch
# 8                 Nintendo Switch                        Splatoon 3
# 9                 Nintendo Switch                          Pikmin 4
# 10                Nintendo Switch    Nintendo Switch Pro Controller
# 11     Joy-Con Controllers (Pair)                   Nintendo Switch
# 12                Nintendo Switch          Nintendo Switch Dock Set
# 13                Nintendo Switch     Nintendo Switch Carrying Case
# 14                Nintendo Switch  Nintendo Switch Screen Protector
#
#     cooccurrence_count
# 0                30000
# 1                50000
# 2                60000
# 3                40000
# 4                20000
# 5                10000
# 6                10000
# 7               100000
# 8                30000
# 9                 5000
# 10               50000
# 11               20000
# 12               10000
# 13               10000
# 14                5000

# %% [markdown]
# ### Save clean data to file

# %%
coocur_df_final.to_csv("./01_clean_data/coocurrences_data.csv", index=False)

# %% [markdown]
# ## Prepare Products Dataset

# %%
import json

with open('./00_raw_data/dataset.json', 'r') as file:
    data_json = json.load(file)

data_json
# Out:
# {'Console': [{'name': 'Nintendo Switch',
#    'Store A': 200000,
#    'Store B': 150000,
#    'Store C': 150000,
#    'category': 'Console',
#    'times_sold': 500000}],
#  'Games': [{'name': 'Zelda: Breath of the Wild',
#    'release_date': '2017-03-03',
#    'times_sold': 250000,
#    'Store A': 120000,
#    'Store B': 80000,
#    'Store C': 50000,
#    'type': 'Adventure',
#    'category': 'Game',
#    'franchise': 'The Legend of Zelda',
#    'min_age': 12},
#   {'name': 'Zelda: Tears of the Kingdom',
#    'release_date': '2023-05-12',
#    'times_sold': 350000,
#    'Store A': 200000,
#    'Store B': 100000,
#    'Store C': 50000,
#    'type': 'Adventure',
#    'category': 'Game',
#    'franchise': 'The Legend of Zelda',
#    'min_age': 12},
#   {'name': 'Super Mario Odyssey',
#    'release_date': '2017-10-27',
#    'times_sold': 400000,
#    'Store A': 150000,
#    'Store B': 100000,
#    'Store C': 150000,
#    'type': 'Platformer',
#    'category': 'Game',
#    'franchise': 'Super Mario',
#    'min_age': 7},
#   {'name': 'Mario Kart 8 Deluxe',
#    'release_date': '2017-04-28',
#    'times_sold': 300000,
#    'Store A': 100000,
#    'Store B': 100000,
#    'Store C': 100000,
#    'type': 'Racing',
#    'category': 'Game',
#    'franchise': 'Super Mario',
#    'min_age': 6},
#   {'name': 'Mario Party Superstars',
#    'release_date': '2021-10-29',
#    'times_sold': 200000,
#    'Store A': 80000,
#    'Store B': 70000,
#    'Store C': 50000,
#    'type': 'Party',
#    'category': 'Game',
#    'franchise': 'Super Mario',
#    'min_age': 6},
#   {'name': 'Sonic Generations',
#    'release_date': '2011-11-01',
#    'times_sold': 180000,
#    'Store A': 60000,
#    'Store B': 60000,
#    'Store C': 60000,
#    'type': 'Platformer',
#    'category': 'Game',
#    'franchise': 'Sonic',
#    'min_age': 10},
#   {'name': 'Sonic Mania',
#    'release_date': '2017-08-15',
#    'times_sold': 250000,
#    'Store A': 150000,
#    'Store B': 100000,
#    'Store C': 0,
#    'type': 'Platformer',
#    'category': 'Game',
#    'franchise': 'Sonic',
#    'min_age': 10},
#   {'name': 'Animal Crossing: New Horizons',
#    'release_date': '2020-03-20',
#    'times_sold': 800000,
#    'Store A': 500000,
#    'Store B': 300000,
#    'Store C': None,
#    'type': 'Simulation',
#    'category': 'Game',
#    'franchise': 'Animal Crossing',
#    'min_age': 3},
#   {'name': 'Splatoon 3',
#    'release_date': '2022-09-09',
#    'times_sold': 500000,
#    'Store A': 200000,
#    'Store B': 150000,
#    'Store C': 150000,
#    'type': 'Shooter',
#    'category': 'Game',
#    'franchise': 'Splatoon',
#    'min_age': 10},
#   {'name': 'Pikmin 4',
#    'release_date': '2023-07-21',
#    'times_sold': 100000,
#    'Store A': 40000,
#    'Store B': 30000,
#    'Store C': 30000,
#    'type': 'Strategy',
#    'category': 'Game',
#    'franchise': 'Pikmin',
#    'min_age': 7}],
#  'Accessories': [{'name': 'Nintendo Switch Pro Controller',
#    'times_sold': 100000,
#    'Store A': 40000,
#    'Store B': 30000,
#    'Store C': 30000,
#    'category': 'Controller',
#    'type': 'Accessory'},
#   {'name': 'Joy-Con Controllers (Pair)',
#    'times_sold': 80000,
#    'Store A': 40000,
#    'Store B': None,
#    'Store C': 40000,
#    'category': 'Controller',
#    'type': 'Accessory'},
#   {'name': 'Nintendo Switch Dock Set',
#    'times_sold': 60000,
#    'Store A': 20000,
#    'Store B': 20000,
#    'Store C': 20000,
#    'category': 'Dock',
#    'type': 'Accessory'},
#   {'name': 'Nintendo Switch Carrying Case',
#    'times_sold': 50000,
#    'Store A': 20000,
#    'Store B': None,
#    'Store C': 30000,
#    'category': 'Case',
#    'type': 'Accessory'},
#   {'name': 'Nintendo Switch Screen Protector',
#    'times_sold': 30000,
#    'Store A': 15000,
#    'Store B': None,
#    'Store C': 15000,
#    'category': 'Screen Protector',
#    'type': 'Accessory'}]}

# %%
#-- Create a flatten dictionary for final format
product_data = []

# fields to exclude from the text field
exclude_fields = {"times_sold", "Store A", "Store B", "Store C"}

for major_category, products in data_json.items():
    for product in products:
        product['major_category'] = major_category

        text_parts = [
            f"{k.upper()}: {v}" for k, v in product.items()
            if k not in exclude_fields and v is not None and k != 'text'
        ]
        product['text'] = '; '.join(text_parts)

        product_data.append(product)

product_data
# Out:
# [{'name': 'Nintendo Switch',
#   'Store A': 200000,
#   'Store B': 150000,
#   'Store C': 150000,
#   'category': 'Console',
#   'times_sold': 500000,
#   'major_category': 'Console',
#   'text': 'NAME: Nintendo Switch; CATEGORY: Console; MAJOR_CATEGORY: Console'},
#  {'name': 'Zelda: Breath of the Wild',
#   'release_date': '2017-03-03',
#   'times_sold': 250000,
#   'Store A': 120000,
#   'Store B': 80000,
#   'Store C': 50000,
#   'type': 'Adventure',
#   'category': 'Game',
#   'franchise': 'The Legend of Zelda',
#   'min_age': 12,
#   'major_category': 'Games',
#   'text': 'NAME: Zelda: Breath of the Wild; RELEASE_DATE: 2017-03-03; TYPE: Adventure; CATEGORY: Game; FRANCHISE: The Legend of Zelda; MIN_AGE: 12; MAJOR_CATEGORY: Games'},
#  {'name': 'Zelda: Tears of the Kingdom',
#   'release_date': '2023-05-12',
#   'times_sold': 350000,
#   'Store A': 200000,
#   'Store B': 100000,
#   'Store C': 50000,
#   'type': 'Adventure',
#   'category': 'Game',
#   'franchise': 'The Legend of Zelda',
#   'min_age': 12,
#   'major_category': 'Games',
#   'text': 'NAME: Zelda: Tears of the Kingdom; RELEASE_DATE: 2023-05-12; TYPE: Adventure; CATEGORY: Game; FRANCHISE: The Legend of Zelda; MIN_AGE: 12; MAJOR_CATEGORY: Games'},
#  {'name': 'Super Mario Odyssey',
#   'release_date': '2017-10-27',
#   'times_sold': 400000,
#   'Store A': 150000,
#   'Store B': 100000,
#   'Store C': 150000,
#   'type': 'Platformer',
#   'category': 'Game',
#   'franchise': 'Super Mario',
#   'min_age': 7,
#   'major_category': 'Games',
#   'text': 'NAME: Super Mario Odyssey; RELEASE_DATE: 2017-10-27; TYPE: Platformer; CATEGORY: Game; FRANCHISE: Super Mario; MIN_AGE: 7; MAJOR_CATEGORY: Games'},
#  {'name': 'Mario Kart 8 Deluxe',
#   'release_date': '2017-04-28',
#   'times_sold': 300000,
#   'Store A': 100000,
#   'Store B': 100000,
#   'Store C': 100000,
#   'type': 'Racing',
#   'category': 'Game',
#   'franchise': 'Super Mario',
#   'min_age': 6,
#   'major_category': 'Games',
#   'text': 'NAME: Mario Kart 8 Deluxe; RELEASE_DATE: 2017-04-28; TYPE: Racing; CATEGORY: Game; FRANCHISE: Super Mario; MIN_AGE: 6; MAJOR_CATEGORY: Games'},
#  {'name': 'Mario Party Superstars',
#   'release_date': '2021-10-29',
#   'times_sold': 200000,
#   'Store A': 80000,
#   'Store B': 70000,
#   'Store C': 50000,
#   'type': 'Party',
#   'category': 'Game',
#   'franchise': 'Super Mario',
#   'min_age': 6,
#   'major_category': 'Games',
#   'text': 'NAME: Mario Party Superstars; RELEASE_DATE: 2021-10-29; TYPE: Party; CATEGORY: Game; FRANCHISE: Super Mario; MIN_AGE: 6; MAJOR_CATEGORY: Games'},
#  {'name': 'Sonic Generations',
#   'release_date': '2011-11-01',
#   'times_sold': 180000,
#   'Store A': 60000,
#   'Store B': 60000,
#   'Store C': 60000,
#   'type': 'Platformer',
#   'category': 'Game',
#   'franchise': 'Sonic',
#   'min_age': 10,
#   'major_category': 'Games',
#   'text': 'NAME: Sonic Generations; RELEASE_DATE: 2011-11-01; TYPE: Platformer; CATEGORY: Game; FRANCHISE: Sonic; MIN_AGE: 10; MAJOR_CATEGORY: Games'},
#  {'name': 'Sonic Mania',
#   'release_date': '2017-08-15',
#   'times_sold': 250000,
#   'Store A': 150000,
#   'Store B': 100000,
#   'Store C': 0,
#   'type': 'Platformer',
#   'category': 'Game',
#   'franchise': 'Sonic',
#   'min_age': 10,
#   'major_category': 'Games',
#   'text': 'NAME: Sonic Mania; RELEASE_DATE: 2017-08-15; TYPE: Platformer; CATEGORY: Game; FRANCHISE: Sonic; MIN_AGE: 10; MAJOR_CATEGORY: Games'},
#  {'name': 'Animal Crossing: New Horizons',
#   'release_date': '2020-03-20',
#   'times_sold': 800000,
#   'Store A': 500000,
#   'Store B': 300000,
#   'Store C': None,
#   'type': 'Simulation',
#   'category': 'Game',
#   'franchise': 'Animal Crossing',
#   'min_age': 3,
#   'major_category': 'Games',
#   'text': 'NAME: Animal Crossing: New Horizons; RELEASE_DATE: 2020-03-20; TYPE: Simulation; CATEGORY: Game; FRANCHISE: Animal Crossing; MIN_AGE: 3; MAJOR_CATEGORY: Games'},
#  {'name': 'Splatoon 3',
#   'release_date': '2022-09-09',
#   'times_sold': 500000,
#   'Store A': 200000,
#   'Store B': 150000,
#   'Store C': 150000,
#   'type': 'Shooter',
#   'category': 'Game',
#   'franchise': 'Splatoon',
#   'min_age': 10,
#   'major_category': 'Games',
#   'text': 'NAME: Splatoon 3; RELEASE_DATE: 2022-09-09; TYPE: Shooter; CATEGORY: Game; FRANCHISE: Splatoon; MIN_AGE: 10; MAJOR_CATEGORY: Games'},
#  {'name': 'Pikmin 4',
#   'release_date': '2023-07-21',
#   'times_sold': 100000,
#   'Store A': 40000,
#   'Store B': 30000,
#   'Store C': 30000,
#   'type': 'Strategy',
#   'category': 'Game',
#   'franchise': 'Pikmin',
#   'min_age': 7,
#   'major_category': 'Games',
#   'text': 'NAME: Pikmin 4; RELEASE_DATE: 2023-07-21; TYPE: Strategy; CATEGORY: Game; FRANCHISE: Pikmin; MIN_AGE: 7; MAJOR_CATEGORY: Games'},
#  {'name': 'Nintendo Switch Pro Controller',
#   'times_sold': 100000,
#   'Store A': 40000,
#   'Store B': 30000,
#   'Store C': 30000,
#   'category': 'Controller',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Nintendo Switch Pro Controller; CATEGORY: Controller; TYPE: Accessory; MAJOR_CATEGORY: Accessories'},
#  {'name': 'Joy-Con Controllers (Pair)',
#   'times_sold': 80000,
#   'Store A': 40000,
#   'Store B': None,
#   'Store C': 40000,
#   'category': 'Controller',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Joy-Con Controllers (Pair); CATEGORY: Controller; TYPE: Accessory; MAJOR_CATEGORY: Accessories'},
#  {'name': 'Nintendo Switch Dock Set',
#   'times_sold': 60000,
#   'Store A': 20000,
#   'Store B': 20000,
#   'Store C': 20000,
#   'category': 'Dock',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Nintendo Switch Dock Set; CATEGORY: Dock; TYPE: Accessory; MAJOR_CATEGORY: Accessories'},
#  {'name': 'Nintendo Switch Carrying Case',
#   'times_sold': 50000,
#   'Store A': 20000,
#   'Store B': None,
#   'Store C': 30000,
#   'category': 'Case',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Nintendo Switch Carrying Case; CATEGORY: Case; TYPE: Accessory; MAJOR_CATEGORY: Accessories'},
#  {'name': 'Nintendo Switch Screen Protector',
#   'times_sold': 30000,
#   'Store A': 15000,
#   'Store B': None,
#   'Store C': 15000,
#   'category': 'Screen Protector',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Nintendo Switch Screen Protector; CATEGORY: Screen Protector; TYPE: Accessory; MAJOR_CATEGORY: Accessories'}]

# %% [markdown]
# ### Save clean data to file

# %%
import json
with open("./01_clean_data/products_data.json", 'w', encoding='utf-8') as f:
    json.dump(product_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Test embeddings creation

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

for product in product_data:
    if "embedding" not in product.keys():
        client = OpenAI(api_key=os.environ["OPENAPI_KEY"])

        response = client.embeddings.create(
            input=product['text'],
            model=os.environ["OPENAI_EMB_MODEL"]
        )

        product["tokens"] = response.usage.total_tokens
        product["embedding"] = response.data[0].embedding

    break

# %%
product_data
# Out:
# [{'name': 'Nintendo Switch',
#   'Store A': 200000,
#   'Store B': 150000,
#   'Store C': 150000,
#   'category': 'Console',
#   'times_sold': 500000,
#   'major_category': 'Console',
#   'text': 'NAME: Nintendo Switch; CATEGORY: Console; MAJOR_CATEGORY: Console',
#   'tokens': 14,
#   'embedding': [0.003805328393355012,
#    0.010521418415009975,
#    -0.03624226525425911,
#    -0.013065598905086517,
#    0.040903862565755844,
#    -0.0028150128200650215,
#    -0.04893581196665764,
#    0.004160966724157333,
#    0.016370298340916634,
#    -0.017508340999484062,
#    0.023898884654045105,
#    0.039109256118535995,
#    -0.017508340999484062,
#    -0.0009321823599748313,
#    0.010023524984717369,
#    0.005304479971528053,
#    -0.00986485555768013,
#    0.02702850103378296,
#    0.019423315301537514,
#    0.005941892974078655,
#    0.055019959807395935,
#    0.034141264855861664,
#    0.031099190935492516,
#    0.015057173557579517,
#    0.023176666349172592,
#    0.058784253895282745,
#    -0.04959237575531006,
#    -0.03298133611679077,
#    -0.0028150128200650215,
#    0.0007967663113959134,
#    0.062154609709978104,
#    -0.02120697870850563,
#    0.02757563628256321,
#    0.0013965637190267444,
#    0.049898769706487656,
#    0.014159870333969593,
#    -0.004051539581269026,
#    -0.050161395221948624,
#    0.018394701182842255,
#    0.02065984159708023,
#    -0.034578971564769745,
#    0.008327404968440533,
#    0.004234829917550087,
#    0.01228866633027792,
#    -0.025321437045931816,
#    0.05112435668706894,
#    -0.09909720718860626,
#    0.004267658106982708,
#    -0.04300486296415329,
#    0.008978496305644512,
#    -0.017322314903140068,
#    -0.03258739784359932,
#    0.01441155280917883,
#    0.00414181686937809,
#    0.03532307595014572,
#    -0.011095911264419556,
#    0.02010176330804825,
#    0.03225911781191826,
#    0.04727252200245857,
#    -0.0338129848241806,
#    -0.010100124403834343,
#    -0.009443561546504498,
#    -0.02691907435655594,
#    0.02262953110039234,
#    0.031186731532216072,
#    -0.028538595885038376,
#    -0.01919351890683174,
#    -0.009498274885118008,
#    0.016337471082806587,
#    -0.016173329204320908,
#    -0.005958307068794966,
#    0.023023467510938644,
#    -0.022607645019888878,
#    -0.0064452579244971275,
#    0.041341569274663925,
#    0.04893581196665764,
#    -0.03819006681442261,
#    -0.03983147442340851,
#    -0.006073205731809139,
#    0.038999829441308975,
#    -0.03503856807947159,
#    0.04105705767869949,
#    -0.058127690106630325,
#    0.012967115268111229,
#    -0.005088361445814371,
#    0.007588771637529135,
#    -0.018722981214523315,
#    -0.001380833564326167,
#    -0.026503250002861023,
#    0.00448377663269639,
#    -0.008404003456234932,
#    -0.04125402867794037,
#    -0.03173386678099632,
#    0.004084367770701647,
#    -0.009974283166229725,
#    -0.003507139626890421,
#    -2.7420899641583674e-05,
#    -0.04959237575531006,
#    -0.011555504985153675,
#    0.04683481156826019,
#    0.019609341397881508,
#    -0.00907150935381651,
#    -0.01913880556821823,
#    0.007528586778789759,
#    -0.0003104994830209762,
#    -0.011347593739628792,
#    -0.00937243364751339,
#    0.004505662247538567,
#    -0.017519284039735794,
#    -0.015549595467746258,
#    -0.02109755016863346,
#    0.027947688475251198,
#    0.04289543628692627,
#    0.012857687659561634,
#    0.012190182693302631,
#    0.021053779870271683,
#    0.009552988223731518,
#    0.01696120575070381,
#    -0.014893032610416412,
#    0.015669964253902435,
#    0.007090878207236528,
#    -0.02980794943869114,
#    0.007834982126951218,
#    0.010576131753623486,
#    0.0222903061658144,
#    -0.009591287933290005,
#    0.03013623133301735,
#    -0.0021228862460702658,
#    0.010532361455261707,
#    0.012846744619309902,
#    0.020703613758087158,
#    ...]},
#  {'name': 'Zelda: Breath of the Wild',
#   'release_date': '2017-03-03',
#   'times_sold': 250000,
#   'Store A': 120000,
#   'Store B': 80000,
#   'Store C': 50000,
#   'type': 'Adventure',
#   'category': 'Game',
#   'franchise': 'The Legend of Zelda',
#   'min_age': 12,
#   'major_category': 'Games',
#   'text': 'NAME: Zelda: Breath of the Wild; RELEASE_DATE: 2017-03-03; TYPE: Adventure; CATEGORY: Game; FRANCHISE: The Legend of Zelda; MIN_AGE: 12; MAJOR_CATEGORY: Games'},
#  {'name': 'Zelda: Tears of the Kingdom',
#   'release_date': '2023-05-12',
#   'times_sold': 350000,
#   'Store A': 200000,
#   'Store B': 100000,
#   'Store C': 50000,
#   'type': 'Adventure',
#   'category': 'Game',
#   'franchise': 'The Legend of Zelda',
#   'min_age': 12,
#   'major_category': 'Games',
#   'text': 'NAME: Zelda: Tears of the Kingdom; RELEASE_DATE: 2023-05-12; TYPE: Adventure; CATEGORY: Game; FRANCHISE: The Legend of Zelda; MIN_AGE: 12; MAJOR_CATEGORY: Games'},
#  {'name': 'Super Mario Odyssey',
#   'release_date': '2017-10-27',
#   'times_sold': 400000,
#   'Store A': 150000,
#   'Store B': 100000,
#   'Store C': 150000,
#   'type': 'Platformer',
#   'category': 'Game',
#   'franchise': 'Super Mario',
#   'min_age': 7,
#   'major_category': 'Games',
#   'text': 'NAME: Super Mario Odyssey; RELEASE_DATE: 2017-10-27; TYPE: Platformer; CATEGORY: Game; FRANCHISE: Super Mario; MIN_AGE: 7; MAJOR_CATEGORY: Games'},
#  {'name': 'Mario Kart 8 Deluxe',
#   'release_date': '2017-04-28',
#   'times_sold': 300000,
#   'Store A': 100000,
#   'Store B': 100000,
#   'Store C': 100000,
#   'type': 'Racing',
#   'category': 'Game',
#   'franchise': 'Super Mario',
#   'min_age': 6,
#   'major_category': 'Games',
#   'text': 'NAME: Mario Kart 8 Deluxe; RELEASE_DATE: 2017-04-28; TYPE: Racing; CATEGORY: Game; FRANCHISE: Super Mario; MIN_AGE: 6; MAJOR_CATEGORY: Games'},
#  {'name': 'Mario Party Superstars',
#   'release_date': '2021-10-29',
#   'times_sold': 200000,
#   'Store A': 80000,
#   'Store B': 70000,
#   'Store C': 50000,
#   'type': 'Party',
#   'category': 'Game',
#   'franchise': 'Super Mario',
#   'min_age': 6,
#   'major_category': 'Games',
#   'text': 'NAME: Mario Party Superstars; RELEASE_DATE: 2021-10-29; TYPE: Party; CATEGORY: Game; FRANCHISE: Super Mario; MIN_AGE: 6; MAJOR_CATEGORY: Games'},
#  {'name': 'Sonic Generations',
#   'release_date': '2011-11-01',
#   'times_sold': 180000,
#   'Store A': 60000,
#   'Store B': 60000,
#   'Store C': 60000,
#   'type': 'Platformer',
#   'category': 'Game',
#   'franchise': 'Sonic',
#   'min_age': 10,
#   'major_category': 'Games',
#   'text': 'NAME: Sonic Generations; RELEASE_DATE: 2011-11-01; TYPE: Platformer; CATEGORY: Game; FRANCHISE: Sonic; MIN_AGE: 10; MAJOR_CATEGORY: Games'},
#  {'name': 'Sonic Mania',
#   'release_date': '2017-08-15',
#   'times_sold': 250000,
#   'Store A': 150000,
#   'Store B': 100000,
#   'Store C': 0,
#   'type': 'Platformer',
#   'category': 'Game',
#   'franchise': 'Sonic',
#   'min_age': 10,
#   'major_category': 'Games',
#   'text': 'NAME: Sonic Mania; RELEASE_DATE: 2017-08-15; TYPE: Platformer; CATEGORY: Game; FRANCHISE: Sonic; MIN_AGE: 10; MAJOR_CATEGORY: Games'},
#  {'name': 'Animal Crossing: New Horizons',
#   'release_date': '2020-03-20',
#   'times_sold': 800000,
#   'Store A': 500000,
#   'Store B': 300000,
#   'Store C': None,
#   'type': 'Simulation',
#   'category': 'Game',
#   'franchise': 'Animal Crossing',
#   'min_age': 3,
#   'major_category': 'Games',
#   'text': 'NAME: Animal Crossing: New Horizons; RELEASE_DATE: 2020-03-20; TYPE: Simulation; CATEGORY: Game; FRANCHISE: Animal Crossing; MIN_AGE: 3; MAJOR_CATEGORY: Games'},
#  {'name': 'Splatoon 3',
#   'release_date': '2022-09-09',
#   'times_sold': 500000,
#   'Store A': 200000,
#   'Store B': 150000,
#   'Store C': 150000,
#   'type': 'Shooter',
#   'category': 'Game',
#   'franchise': 'Splatoon',
#   'min_age': 10,
#   'major_category': 'Games',
#   'text': 'NAME: Splatoon 3; RELEASE_DATE: 2022-09-09; TYPE: Shooter; CATEGORY: Game; FRANCHISE: Splatoon; MIN_AGE: 10; MAJOR_CATEGORY: Games'},
#  {'name': 'Pikmin 4',
#   'release_date': '2023-07-21',
#   'times_sold': 100000,
#   'Store A': 40000,
#   'Store B': 30000,
#   'Store C': 30000,
#   'type': 'Strategy',
#   'category': 'Game',
#   'franchise': 'Pikmin',
#   'min_age': 7,
#   'major_category': 'Games',
#   'text': 'NAME: Pikmin 4; RELEASE_DATE: 2023-07-21; TYPE: Strategy; CATEGORY: Game; FRANCHISE: Pikmin; MIN_AGE: 7; MAJOR_CATEGORY: Games'},
#  {'name': 'Nintendo Switch Pro Controller',
#   'times_sold': 100000,
#   'Store A': 40000,
#   'Store B': 30000,
#   'Store C': 30000,
#   'category': 'Controller',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Nintendo Switch Pro Controller; CATEGORY: Controller; TYPE: Accessory; MAJOR_CATEGORY: Accessories'},
#  {'name': 'Joy-Con Controllers (Pair)',
#   'times_sold': 80000,
#   'Store A': 40000,
#   'Store B': None,
#   'Store C': 40000,
#   'category': 'Controller',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Joy-Con Controllers (Pair); CATEGORY: Controller; TYPE: Accessory; MAJOR_CATEGORY: Accessories'},
#  {'name': 'Nintendo Switch Dock Set',
#   'times_sold': 60000,
#   'Store A': 20000,
#   'Store B': 20000,
#   'Store C': 20000,
#   'category': 'Dock',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Nintendo Switch Dock Set; CATEGORY: Dock; TYPE: Accessory; MAJOR_CATEGORY: Accessories'},
#  {'name': 'Nintendo Switch Carrying Case',
#   'times_sold': 50000,
#   'Store A': 20000,
#   'Store B': None,
#   'Store C': 30000,
#   'category': 'Case',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Nintendo Switch Carrying Case; CATEGORY: Case; TYPE: Accessory; MAJOR_CATEGORY: Accessories'},
#  {'name': 'Nintendo Switch Screen Protector',
#   'times_sold': 30000,
#   'Store A': 15000,
#   'Store B': None,
#   'Store C': 15000,
#   'category': 'Screen Protector',
#   'type': 'Accessory',
#   'major_category': 'Accessories',
#   'text': 'NAME: Nintendo Switch Screen Protector; CATEGORY: Screen Protector; TYPE: Accessory; MAJOR_CATEGORY: Accessories'}]

# %%
import json
with open("./01_clean_data/products_data.json", 'w', encoding='utf-8') as f:
    json.dump(product_data, f, ensure_ascii=False, indent=4)
